# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/CienciaDatos/blob/main/Semana5/VentasDiasPredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
np.random.seed(42)
idx = pd.date_range('2025-08-01',periods=24*30, freq='H')
ventas = 100 + 10*np.sin(2*np.pi*idx.hour/24) + np.random.normal(0,10,len(idx))

df = pd.DataFrame({'FechaHora': idx, 'Ventas':ventas})
df['Hora'] = df['FechaHora'].dt.hour
df['DiaSemana'] = df['FechaHora'].dt.dayofweek
#df
# Out:
# /tmp/ipython-input-3132652952.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   idx = pd.date_range('2025-08-01',periods=24*30, freq='H')

# %%
# Como se hace con pandas
df['SMA_3'] = df['Ventas'].shift(1).rolling(3).mean()
# Lags
df['lag1'] = df['Ventas'].shift(1)

# Codificacion ciclica de la hora
df['Hora_sin'] = np.sin(2*np.pi*df['Hora']/24)
df['Hora_cos'] = np.cos(2*np.pi*df['Hora']/24)

# %%
df
# Out:
#               FechaHora      Ventas  Hora  DiaSemana       SMA_3        lag1  \
# 0   2025-08-01 00:00:00  104.967142     0          4         NaN         NaN
# 1   2025-08-01 01:00:00  101.205547     1          4         NaN  104.967142
# 2   2025-08-01 02:00:00  111.476885     2          4         NaN  101.205547
# 3   2025-08-01 03:00:00  122.301366     3          4  105.883191  111.476885
# 4   2025-08-01 04:00:00  106.318720     4          4  111.661266  122.301366
# ..                  ...         ...   ...        ...         ...         ...
# 715 2025-08-30 19:00:00  101.373761    19          5   89.948770   89.623653
# 716 2025-08-30 20:00:00   92.482022    20          5   95.109839  101.373761
# 717 2025-08-30 21:00:00   94.431950    21          5   94.493145   92.482022
# 718 2025-08-30 22:00:00   91.363878    22          5   96.095911   94.431950
# 719 2025-08-30 23:00:00   96.842353    23          5   92.759283   91.363878
#
#      Hora_sin  Hora_cos
# 0    0.000000  1.000000
# 1    0.258819  0.965926
# 2    0.500000  0.866025
# 3    0.707107  0.707107
# 4    0.866025  0.500000
# ..        ...       ...
# 715 -0.965926  0.258819
# 716 -0.866025  0.500000
# 717 -0.707107  0.707107
# 718 -0.500000  0.866025
# 719 -0.258819  0.965926
#
# [720 rows x 8 columns]

# %%
# Esquema one-hot encoding
df = pd.get_dummies(df, columns=['DiaSemana'], drop_first=True)
df = df.dropna()

# %%
df
# Out:
#               FechaHora      Ventas  Hora       SMA_3        lag1  Hora_sin  \
# 3   2025-08-01 03:00:00  122.301366     3  105.883191  111.476885  0.707107
# 4   2025-08-01 04:00:00  106.318720     4  111.661266  122.301366  0.866025
# 5   2025-08-01 05:00:00  107.317889     5  113.365657  106.318720  0.965926
# 6   2025-08-01 06:00:00  125.792128     6  111.979325  107.317889  1.000000
# 7   2025-08-01 07:00:00  117.333606     7  113.142912  125.792128  0.965926
# ..                  ...         ...   ...         ...         ...       ...
# 715 2025-08-30 19:00:00  101.373761    19   89.948770   89.623653 -0.965926
# 716 2025-08-30 20:00:00   92.482022    20   95.109839  101.373761 -0.866025
# 717 2025-08-30 21:00:00   94.431950    21   94.493145   92.482022 -0.707107
# 718 2025-08-30 22:00:00   91.363878    22   96.095911   94.431950 -0.500000
# 719 2025-08-30 23:00:00   96.842353    23   92.759283   91.363878 -0.258819
#
#          Hora_cos  DiaSemana_1  DiaSemana_2  DiaSemana_3  DiaSemana_4  \
# 3    7.071068e-01        False        False        False         True
# 4    5.000000e-01        False        False        False         True
# 5    2.588190e-01        False        False        False         True
# 6    6.123234e-17        False        False        False         True
# 7   -2.588190e-01        False        False        False         True
# ..            ...          ...          ...          ...          ...
# 715  2.588190e-01        False        False        False        False
# 716  5.000000e-01        False        False        False        False
# 717  7.071068e-01        False        False        False        False
# 718  8.660254e-01        False        False        False        False
# 719  9.659258e-01        False        False        False        False
#
#      DiaSemana_5  DiaSemana_6
# 3          False        False
# 4          False        False
# 5          False        False
# 6          False        False
# 7          False        False
# ..           ...          ...
# 715         True        False
# 716         True        False
# 717         True        False
# 718         True        False
# 719         True        False
#
# [717 rows x 13 columns]

# %%
# Separar entre muestra de entrenamiento y muestra de prueba
split = int(len(df)*0.8)
df_train = df.iloc[:split]
df_test = df.iloc[split:]

# %%
X_train = df_train.drop(columns=['FechaHora','Ventas'])
y_train = df_train['Ventas']
X_test = df_test.drop(columns=['FechaHora','Ventas'])
y_test = df_test['Ventas']

# %%
# Construcción del modelo
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %%
def metrics(y_true, y_pred):
    return {
        "R2": r2_score(y_true, y_pred),
        "MAE": mean_absolute_error(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred),
    }

# %%
print("Métricas TRAIN:", metrics(y_train, y_pred_train))
print("Métricas TEST :", metrics(y_test,  y_pred_test))
# Out:
# Métricas TRAIN: {'R2': 0.34222659040764336, 'MAE': 7.706809022892099, 'RMSE': 94.63105213984213}
# Métricas TEST : {'R2': 0.32990236313860233, 'MAE': 8.182171252321174, 'RMSE': 106.40893467724766}

# %%
plt.figure(figsize=(12,5))
#plt.plot(df_train['FechaHora'], df_train['Ventas'], label='Entrenamiento')
plt.plot(df_test['FechaHora'], df_test['Ventas'], label='Datos de Prueba', marker='o')
plt.plot(df_test['FechaHora'], y_pred_test, label='Prediccion', linestyle='--')
plt.legend()
plt.show()

# %%
for name, coef in zip(X_train.columns, model.coef_):
  print(f"{name}: {coef}")
# Out:
# Hora: -0.026120670623607116
# SMA_3: -0.004477554057740418
# lag1: -0.017055774696083603
# Hora_sin: 9.762672992036805
# Hora_cos: -0.9811338881775681
# DiaSemana_1: -0.4128716364876794
# DiaSemana_2: 0.6420753894176894
# DiaSemana_3: 1.3094369701109239
# DiaSemana_4: -1.9115649589436194
# DiaSemana_5: 0.1520644805271646
# DiaSemana_6: 0.0930100261663828

# %%
# quiero hacer una red neuronal sencilla
from sklearn.neural_network import MLPRegressor
model1 = MLPRegressor(hidden_layer_sizes=(200,50), max_iter=1000, random_state=42)
model1.fit(X_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(200, 50), max_iter=1000, random_state=42)

# %%
y_pred_train1 = model1.predict(X_train)
y_pred_test1  = model1.predict(X_test)

# %%
print("Métricas TRAIN:", metrics(y_train, y_pred_train1))
print("Métricas TEST :", metrics(y_test,  y_pred_test1))
# Out:
# Métricas TRAIN: {'R2': 0.17435632567405435, 'MAE': 8.716115671837473, 'RMSE': 118.78183042164933}
# Métricas TEST : {'R2': 0.13256569454968103, 'MAE': 9.345447693074833, 'RMSE': 137.74524079475077}

# %%
plt.figure(figsize=(12,5))
plt.plot(df_test["FechaHora"], y_test, label="Ventas reales", marker="o")
plt.plot(df_test["FechaHora"], y_pred_test1, label="Predicción", linestyle="--")
plt.legend()
plt.title("Regresión con media móvil + variables adicionales")
plt.xticks(rotation=45)
plt.show()
